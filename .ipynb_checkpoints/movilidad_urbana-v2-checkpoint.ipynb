# %% [markdown]
# # Analisis de la movilidad urbana utilizando estadisticas del Comoir

# %% [markdown]
# En este notebook intento realizar un analisis geoespacial de la movilidad urbana utilizando como fuente de datos las estadisticas de uso de la aplicacion Comoir publicadas por la IMM.
#
# Primero lo primero - Las librerias que voy a precisar!

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pysal as ps
import geopandas as gpd
from sklearn import cluster
from sklearn.preprocessing import scale
import shapely
from pyproj import Proj, transform

# %matplotlib inline

# %%
SEPARADOR = ';'
AÑO = 2010

dict_estadist = {2010:'comoir/comoir_2010_01_12.csv.gz', 
                 2011:'comoir/comoir_2011_01_12.csv.gz', 
                 2012:'comoir/comoir_2012_01_12.csv.gz', 
                 2013:'comoir/comoir_2013_01_12.csv.gz', 
                 2014:'comoir/comoir_2014_01_06.csv.gz'}

# %%
# Out:
# 'Estadisticas comoir (2010)'

# %% [markdown]
# Algunas referencias a los archivos shapefile y csv para luego poder cargar los que realmetne necesito. Al momento de empezar con el notebook no tengo ni idea de cuales me van a servir y cuales no. Bueno, en realidad se que los csv con las estadisticas de las consultas realizadas por los usuarios los preciso, sino para que estoy haciendo esto?

# %%
barrios_shp_path = 'barrios/barrios.shp' #shapefile con los barrios de montevideo
vias_shp_path = 'v_mdg_vias/v_mdg_vias.shp' #shapefile con las vias (calles, caminos, pasajes, etc.) de mvdeo
destino_shp_path = 'v_uptu_lsv_destinos/v_uptu_lsv_destinos.shp' #shapefile con los destino... ni se porque lo baje
ejes_shp_path = 'ejesinv/ejesinv.shp' # ejes de las calles. Tiene todas llas "cuadras" de cada calle.
codpost_shp_path = 'cpost/cpost.shp' # poligonos de los distintos codigos postales de montevideo 

manzanas_shp_path = 'v_mdg_manzanas/v_mdg_manzanas.shp' #shapefile con las manzanas
accesos_shp_path = 'v_mdg_accesos/v_mdg_accesos.shp' #shapefile con las calles y su numeracion. 
cultura_csv_path = 'v_uptu_lugares/uptu_cultura.csv.gz' #shapefile con la ubicacion de los centros culturales
deporte_csv_path = 'v_uptu_lugares/uptu_deporte.csv.gz' #shapefile con los lugares centros deportivos
educacion_csv_path = 'v_uptu_lugares/uptu_educacion.csv.gz' #shapefile con los centros educativos 
patrimonio_csv_path = 'v_uptu_lugares/uptu_patrimonio.csv.gz' #shapefile con los lugares patrimoniales
playa_csv_path = 'v_uptu_lugares/uptu_playa.csv.gz' #shapefile con las playas
salud_csv_path = 'v_uptu_lugares/uptu_salud.csv.gz' #shapefile con los centros de salud
espacios_shp_path = 'v_mdg_espacios_libres/v_mdg_espacios_libres.shp' #shapefile de espacios libres (parques, plazas, etc)
monumentos_shp_path = 'v_mdg_ubicaciones_notables/v_mdg_ubicaciones_notables.shp' #shapefile de monumentos

# %% [markdown]
# Los datos con las estadisticas estan separados en 1 archivo por año. Del 2010 al 2013 inclusive, contienen la información todo el año, mientras que el 2014 solo incluye información del primer semestre de ese año. Las busquedas que se pueden hacer en Comoir son de 3 tipos por cada punto del recorrido (origen y destino) lo que da un total de 6 tipos diferentes combinados. Las busquedas pueden hacerse por:
#     - Esquina: curce de calles
#     - Dirección: calle y número
#     - Lugar de interés
#
# Cada csv indica el tipo de origen, el tipo de destino, y para cada uno de ellos se indica 1 o 2 códigos. Si el tipo del punto es dirección o lugar de interes, el código identifica la calle o el lugar de interes respectivamente. Si el tipo del punto es esquina, se indican dos codigos, donde el primero identifica una calle y el segundo la otra. Los códigos hacen referencia a los otros shapefile, para las calles se hace referencia a ejes_shp_path, y para lugares de interes se hace referencia a cultura_shp_path, deporte_shp_path, educacion_shp_path, patrimonio_shp_path, playa_shp_path, salud_shp_path, espacios_shp_path y monumentos_shp_path. Para las direcciones numeradas (calle y numero de puerta) se hace referencia al shapefile accesos_shp_path.

# %%
#Levanto los lugares de interes y agrego a cada dataframe el tipo y las coordenadas (x,y)
cu = pd.read_csv(cultura_csv_path, delimiter=SEPARADOR)      #cultura         - tipo 3
de = pd.read_csv(deporte_csv_path, delimiter=SEPARADOR)      #deporte         - tipo 4
ed = pd.read_csv(educacion_csv_path, delimiter=SEPARADOR)    #educacion       - tipo 5
pa = pd.read_csv(patrimonio_csv_path, delimiter=SEPARADOR)   #patrimonio      - tipo 9
pl = pd.read_csv(playa_csv_path, delimiter=SEPARADOR)        #playa           - tipo 10
sa = pd.read_csv(salud_csv_path, delimiter=SEPARADOR)        #salud           - tipo 11
el = gpd.read_file(espacios_shp_path)   #espacios libres - tipo 6 espacio libre
pq = el[np.isfinite(el['COD_NOM_PA'])]  #parques         - tipo 7
el = el[np.isfinite(el['COD_NOM_ES'])]  #espacio libre   - tipo 6
mo = gpd.read_file(monumentos_shp_path) #monumentos      - tipo 8

cu.loc[:,'tipo'] = 3
de.loc[:,'tipo'] = 4
ed.loc[:,'tipo'] = 5
pa.loc[:,'tipo'] = 9
pl.loc[:,'tipo'] = 10
sa.loc[:,'tipo'] = 11
el.loc[:,'tipo'] = 6
el.loc[:,'codigo'] = el['COD_NOM_ES'].apply(lambda c: c)
el.loc[:,'x'] = el['geometry'].apply(lambda p: p.centroid.x)
el.loc[:,'y'] = el['geometry'].apply(lambda p: p.centroid.y)
pq.loc[:,'tipo'] = 7
pq.loc[:,'codigo'] = pq['COD_NOM_PA'].apply(lambda c: c)
pq.loc[:,'x'] = pq['geometry'].apply(lambda p: p.centroid.x)
pq.loc[:,'y'] = pq['geometry'].apply(lambda p: p.centroid.y)
mo.loc[:,'x'] = mo['geometry'].apply(lambda p: p.x)
mo.loc[:,'y'] = mo['geometry'].apply(lambda p: p.y)
mo = mo.dropna(subset=['COD_NOM_UB'])
mo.loc[:,'tipo'] = 8
mo.loc[:,'codigo'] = mo['COD_NOM_UB'].apply(lambda c: c)

# %%
#Uno todos los lugares de interes en un solo dataframe con el codigo, tipo y las coordenadas (x,y) de cada uno.
lugares_interes = cu.append(de.append(ed.append(pa.append(pl.append(sa.append(pq.append(el.append(mo,ignore_index=True),
                                                                              ignore_index=True),
                                                                    ignore_index=True),
                                                          ignore_index=True),
                                                ignore_index=True),
                                      ignore_index=True), 
                            ignore_index=True), 
                  ignore_index=True)
lugares_interes = lugares_interes[['codigo', 'tipo', 'x', 'y']]

# %%
del cu, de, ed, pa, pl, sa, el, pq, mo

# %%
#Levanto las "cuadras" de cada calle y las agrupo por codigo para luego unir todas las cuadras de cada calle en una sola coleccion
calles = gpd.read_file(ejes_shp_path) 
calles = calles.groupby('CODIGO')['geometry'].agg({'geometry': lambda x: shapely.ops.linemerge(x.values)})
calles.loc[:,'codigo'] = calles.index
calles.loc[:,'tipo'] = 1

# %%
#Levanto las calles con su numeracion
c_nums = gpd.read_file(accesos_shp_path) 
c_nums.loc[:,'direccion'] = c_nums['NOM_CALLE'] + ' ' + c_nums['NUM_PUERTA'].map(str)
c_nums.loc[:,'x'] = c_nums['geometry'].apply(lambda p: p.x)
c_nums.loc[:,'y'] = c_nums['geometry'].apply(lambda p: p.y)
c_nums.loc[:,'tipo'] = 2
c_nums = c_nums[['COD_NOMBRE', 'tipo', 'direccion','x','y']] #para cada direccion posible tengo las coordenadas (x,y).

# %%
#Levanto las consultas realizadas en la aplicacion del 2010 al 2014.
cir_data = pd.read_csv(dict_estadist[AÑO], low_memory=False, delimiter=SEPARADOR)

# %%
d_li = cir_data.merge(lugares_interes, left_on=['codigo_destino_1', 'tipo_destino'], 
                      right_on=['codigo', 'tipo'], how='inner')
d_li = d_li.drop_duplicates(subset=['id'], keep='first')

d_cc = cir_data.merge(calles, left_on=['codigo_destino_1', 'tipo_destino'], 
                      right_on=['codigo', 'tipo'], how='inner')\
                 .merge(calles, left_on=['codigo_destino_2', 'tipo_destino'], 
                        right_on=['codigo', 'tipo'], how='inner')
d_cc = d_cc.drop_duplicates(subset=['id'], keep='first')

# %%
cd = cir_data[cir_data['tipo_destino'] == 2]
dd = c_nums[c_nums['COD_NOMBRE'].isin(cd['codigo_destino_1'].values)]
cd = cd[cd['desc_destino'].isin(c_nums['direccion'].values)]

# %%
d_cn = cd.merge(dd, left_on=['desc_destino'], right_on=['direccion'], how='inner')\
            .drop_duplicates(subset=['id'], keep='first')
d_cn = d_cn.drop_duplicates(subset=['id'], keep='first')

# %%
d_li = d_li[['id', 'sesion', 'tipo_origen', 'codigo_origen_1', 'codigo_origen_2', 'desc_origen', 
             'tipo_destino', 'codigo_destino_1', 'codigo_destino_2', 'desc_destino', 'x', 'y']]
d_li = d_li.rename(columns={'x': 'x_d', 'y': 'y_d'})

d_cn = d_cn[['id', 'sesion', 'tipo_origen', 'codigo_origen_1', 'codigo_origen_2', 'desc_origen', 
             'tipo_destino', 'codigo_destino_1', 'codigo_destino_2', 'desc_destino', 'x', 'y']]
d_cn = d_cn.rename(columns={'x': 'x_d', 'y': 'y_d'})

d_cc = d_cc[['id', 'sesion', 'tipo_origen', 'codigo_origen_1', 'codigo_origen_2', 'desc_origen', 
             'tipo_destino', 'codigo_destino_1', 'codigo_destino_2', 'desc_destino', 'geometry_x', 'geometry_y']]
d_cc = d_cc.rename(columns={'geometry_x': 'geometry_d1', 'geometry_y': 'geometry_d2'})

# %%
d_cc.loc[:,'punto_d'] = pd.np.nan

# %%
def prueba(limite):
    cont = 0
    for row in d_cc.itertuples():
        cont = cont + 1
        row.geometry_d1.intersection(row.geometry_d2)
        if cont == limite:
            break
            
def find_point():
    puntos = []
    for row in d_cc.itertuples():
        puntos. row.geometry_d1.intersection(row.geometry_d2)

# %%
#%time prueba(1000)
# Out:
# CPU times: user 595 ms, sys: 3.71 ms, total: 599 ms
# Wall time: 599 ms

# %%
#%time prueba(10000)
# Out:
# CPU times: user 6.77 s, sys: 70.1 ms, total: 6.84 s
# Wall time: 7.01 s

# %%
#%time prueba(100000)
# Out:
# CPU times: user 1min 8s, sys: 338 ms, total: 1min 9s
# Wall time: 1min 9s

# %%
#%time find_point()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-1ba2dad679b7> in <module>()
# ----> 1 get_ipython().magic('time find_point()')
#
# /Users/danielbonini/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /Users/danielbonini/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-59> in time(self, line, cell, local_ns)
#
# /Users/danielbonini/anaconda/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /Users/danielbonini/anaconda/lib/python3.6/site-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1174         if mode=='eval':
#    1175             st = clock2()
# -> 1176             out = eval(code, glob, local_ns)
#    1177             end = clock2()
#    1178         else:
#
# <timed eval> in <module>()
#
# <ipython-input-80-fbbf5a2dd74e> in find_point()
#       9 def find_point():
#      10     for row in d_cc.itertuples():
# ---> 11         d_cc[row.index,'punto_d'] = row.geometry_d1.intersection(row.geometry_d2)
#
# /Users/danielbonini/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2417         else:
#    2418             # set column
# -> 2419             self._set_item(key, value)
#    2420
#    2421     def _setitem_slice(self, key, value):
#
# /Users/danielbonini/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2483
#    2484         self._ensure_valid_index(value)
# -> 2485         value = self._sanitize_column(key, value)
#    2486         NDFrame._set_item(self, key, value)
#    2487
#
# /Users/danielbonini/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    2682
#    2683         # broadcast across multiple columns if necessary
# -> 2684         if broadcast and key in self.columns and value.ndim == 1:
#    2685             if (not self.columns.is_unique or
#    2686                     isinstance(self.columns, MultiIndex)):
#
# /Users/danielbonini/anaconda/lib/python3.6/site-packages/pandas/indexes/base.py in __contains__(self, key)
#    1391
#    1392     def __contains__(self, key):
# -> 1393         hash(key)
#    1394         # work around some kind of odd cython bug
#    1395         try:
#
# TypeError: unhashable type: 'MultiLineString'

# %%
# %time d_cc['punto_d'] = d_cc.apply(lambda row: row.geometry_d1.intersection(row.geometry_d2), axis=1)
# Out:
# CPU times: user 21min 5s, sys: 6.55 s, total: 21min 11s
# Wall time: 43min 32s

# %%
def get_xy(punto, coord):
    if isinstance(punto, float):
        return punto
    elif isinstance(punto, shapely.geometry.Point):
        return punto.xy[coord][0]
    elif isinstance(punto, shapely.geometry.MultiPoint):
        return punto[0].xy[coord][0]
    elif punto.is_empty:
        return pd.np.nan

# %%
d_cc.loc[:,'x_d'] = d_cc['punto_d'].apply(lambda p: get_xy(p,0))
d_cc.loc[:,'y_d'] = d_cc['punto_d'].apply(lambda p: get_xy(p,1))
d_cc = d_cc.dropna(subset=['x_d'])

# %%
destinos = d_li.append(d_cn.append(d_cc, ignore_index=True), ignore_index=True)

# %%
destinos['geometry'] = destinos[['x_d', 'y_d']].apply(shapely.geometry.Point, axis=1)

# %%
destinos = destinos.drop(['geometry_d1','geometry_d2','punto_d'], axis=1)

# %%
destinos['codigo_destino_1'].fillna(value=-1,inplace=True)
destinos['codigo_destino_2'].fillna(value=-1,inplace=True)

# %%
del d_li, d_cn, d_cc, cd, dd, c_nums, calles, ejes

# %%
barrios = gpd.read_file(barrios_shp_path)
barrios.index = barrios.NROBARRIO

# %%
dist_dest = destinos.drop_duplicates(subset=['x_d','y_d'], keep='first')[['x_d','y_d']]
gds = gpd.GeoDataFrame(destinos, crs={'init': 'epsg:31981'}, geometry='geometry')

# %%
from geopandas.tools import sjoin
barrios.crs = crs={'init': 'epsg:31981'}
destsEnBarrios = sjoin(barrios, gds, how='left')

# %%
barrios.loc[:,'Busquedas'] = destsEnBarrios.groupby('NROBARRIO').size()

# %%
# Set up figure and axis
f, ax = plt.subplots(1, figsize=(16, 16))
# Plot the equal interval choropleth and add a legend
barrios.plot(column='Busquedas', scheme='Quantiles', legend=True, \
           ax=ax, cmap='RdYlBu', linewidth=0.3)
# Remove the axes
ax.set_axis_off()
# Set the title
ax.set_title("Intensidad de destinos en intervalos iguales en Montevideo")
# Keep axes proportionate
plt.axis('equal')
# Draw map
plt.show()

# %% [markdown]
# En ***dist_dest*** y ***dist_origs*** tengo las coordenadas de los diferentes origenes y destinos consultados por los usuarios. Ahora deberia tomar esos puntos y hacer lo siguiente:
# * Plotear los barrios de montevideo en algun color base que no moleste a los capas superiores
# * Plotear los origenes en algun color que contraste bien con el fondo
# * Plotear los destinos en algun color que contraste bien con el fondo
# * Plotear en una cuarta capa la cantidad de puntos referenciando destinos que contiene cada poligono para dar una idea de la intensidad de las busquedas. Esto seria el mapa de calor

# %%
#['#ffffb2','#fed976','#feb24c','#fd8d3c','#fc4e2a','#e31a1c','#b10026']
#['#ffffb2','#fecc5c','#fd8d3c','#f03b20','#bd0026']
b201x = np.array(barrios.Busquedas)
bins_qk = ps.Quantiles(b201x, k=7)
colorsk = ['#ffffb2','#fed976','#feb24c','#fd8d3c','#fc4e2a','#e31a1c','#b10026']
colors = [colorsk[i] for i in bins_qk.yb]

# %%
def gpd_bokeh(df):
    """Convert geometries from geopandas to bokeh format"""
    nan = float('nan')
    lons = []
    lats = []
    for i,shape in enumerate(df.geometry.values):
        if shape.geom_type == 'MultiPolygon':
            gx = []
            gy = []
            ng = len(shape.geoms) - 1
            for j,member in enumerate(shape.geoms):
                xy = np.array(list(member.exterior.coords))
                xs = xy[:,0].tolist()
                ys = xy[:,1].tolist()
                gx.extend(xs)
                gy.extend(ys)
                if j < ng:
                    gx.append(nan)
                    gy.append(nan)
            lons.append(gx)
            lats.append(gy)
                
        else:     
            xy = np.array(list(shape.exterior.coords))
            xs = xy[:,0].tolist()
            ys = xy[:,1].tolist()
            lons.append(xs)
            lats.append(ys) 

    return lons,lats

# %%
lons, lats = gpd_bokeh(barrios)

# %%
from bokeh.models import HoverTool
from bokeh.plotting import figure, show, output_file, ColumnDataSource

# %%
source = ColumnDataSource(data=dict(
        x=lons,
        y=lats,
        color=colors,
        name=barrios.BARRIO,
        rate=b201x
    ))

TOOLS = "pan, wheel_zoom, box_zoom, reset, hover, save"
p = figure(title="Movilidad Urbana Como Ir (" str(AÑO) + ")", tools=TOOLS,
          plot_width=900, plot_height=600)

p.patches('x', 'y', source=source,
         fill_color='color', fill_alpha=0.7,
         line_color='white', line_width=0.5)

hover = p.select_one(HoverTool)
hover.point_policy = 'follow_mouse'
hover.tooltips = [
    ("Barrio", "@name"),
    ("Busquedas", "@rate"),
    ("(Long, Lat)", "($x, $y)"),
]


output_file("comoir"+str(AÑO)+".html", title="comoir"+str(AÑO)+".py example")
show(p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-e38f95f799ea> in <module>()
#       4         color='autumn',
#       5         name=barrios.BARRIO,
# ----> 6         rate=b2010
#       7     ))
#       8
#
# /Users/danielbonini/anaconda/lib/python3.6/site-packages/bokeh/models/sources.py in __init__(self, *args, **kw)
#      97         super(ColumnDataSource, self).__init__(**kw)
#      98         for name, data in raw_data.items():
# ---> 99             self.add(data, name)
#     100
#     101     @staticmethod
#
# /Users/danielbonini/anaconda/lib/python3.6/site-packages/bokeh/models/sources.py in add(self, data, name)
#     173             name = "Series %d"%n
#     174         self.column_names.append(name)
# --> 175         self.data[name] = data
#     176         return name
#     177
#
# /Users/danielbonini/anaconda/lib/python3.6/site-packages/bokeh/core/property/containers.py in wrapper(self, *args, **kwargs)
#      75         old = self._saved_copy()
#      76         result = func(self, *args, **kwargs)
# ---> 77         self._notify_owners(old)
#      78         return result
#      79     wrapper.__doc__ = "Container method ``%s`` instrumented to notify property owners" % func.__name__
#
# /Users/danielbonini/anaconda/lib/python3.6/site-packages/bokeh/core/property/containers.py in _notify_owners(self, old, hint)
#     105         self._unmodified_default_value = False
#     106         for (owner, prop) in self._owners:
# --> 107             prop._notify_mutated(owner, old, hint)
#     108
#     109     def _saved_copy(self):
#
# /Users/danielbonini/anaconda/lib/python3.6/site-packages/bokeh/core/property/descriptors.py in _notify_mutated(self, obj, old, hint)
#     793         # re-validate because the contents of 'old' have changed,
#     794         # in some cases this could give us a new object for the value
# --> 795         value = self.property.prepare_value(obj, self.name, value)
#     796
#     797         self._real_set(obj, old, value, hint)
#
# /Users/danielbonini/anaconda/lib/python3.6/site-packages/bokeh/core/property/bases.py in prepare_value(self, obj_or_cls, name, value)
#     266                     break
#     267             else:
# --> 268                 raise e
#     269         else:
#     270             value = self.transform(value)
#
# /Users/danielbonini/anaconda/lib/python3.6/site-packages/bokeh/core/property/bases.py in prepare_value(self, obj_or_cls, name, value)
#     259     def prepare_value(self, obj_or_cls, name, value):
#     260         try:
# --> 261             self.validate(value)
#     262         except ValueError as e:
#     263             for tp, converter in self.alternatives:
#
# /Users/danielbonini/anaconda/lib/python3.6/site-packages/bokeh/core/properties.py in validate(self, value)
#    1288             if not (isinstance(value, dict) and \
#    1289                     all(self.keys_type.is_valid(key) and self.values_type.is_valid(val) for key, val in iteritems(value))):
# -> 1290                 raise ValueError("expected an element of %s, got %r" % (self, value))
#    1291
#    1292     def _sphinx_type(self):
#
# ValueError: expected an element of ColumnData(String, Seq(Any)), got {'x': [[583490.7399909726, 583327.8172206427, 582601.6751107725, 582265.5519331675, 582163.9044875938, 581690.2391190509, 581565.7253448787, 581532.9661841613, 580700.9743133031, 580698.3381877027, 580488.7836431949, 580474.785194973, 580435.4681267396, 580302.3114844414, 580239.2605282094, 580223.2201486372, 580182.3723797412, 580030.7898766347, 579919.191134794, 579821.9131468979, 579818.8871911336, 579646.0606580168, 579027.6396841822, 579019.6446078288, 578999.8544444204, 579002.6195493422, 578994.1911439209, 578307.4439030308, 578362.2540706629, 578367.5134369512, 578407.6145990334, 578376.0131794614, 578239.5598279127, 577974.261179596, 577840.2189922091, 577267.9800035757, 577255.3996467005, 576786.7060291563, 576771.7574195757, 576698.6387112268, 576418.7895945406, 576124.1559950329, 576101.8173926717, 575970.2740425685, 575911.2771024214, 575814.43152776, 575654.8199969901, 575496.0082717154, 575375.0887453883, 575208.0558494745, 575197.0612176831, 575014.6596307154, 574872.4486584316, 574670.3117629748, 574658.2551431363, 574637.6996168083, 574607.3742954872, 574586.2655627104, 574520.9032840425, 574486.8503836858, 574519.9364435046, 574493.7099442098, 574499.2744236733, 574504.8273805823, 574448.4111135306, 574403.4924530206, 574365.2420688458, 574345.146885268, 574334.7992935146, 574299.4424360807, 574273.3482659276, 574308.5837724966, 574282.472294511, 574277.3782989546, 574335.9352905522, 574354.3997088259, 574360.6076566275, 574389.4311701637, 574442.7008614389, 574459.841730744, 574475.4618666096, 574483.3524931388, 574485.6180027286, 574484.0890426167, 574501.4658270393, 574496.1481492337, 574503.903951185, 574487.3269970698, 574495.0104595317, 574470.9604741605, 574461.926412189, 574485.0836452079, 574515.3374352484, 574545.464641884, 574569.9864622961, 574611.5537751387, 574661.1160991646, 574683.0682578052, 574682.422120611, 574666.0785653166, 574658.7690970469, 574666.5733752
# 19     1007                       MUSEO DE LA CASA DE GOBIERNO
# 20     1008                               MUSEO DE LA FARMACIA
# 21     1015                                MUSEO DE LA PALABRA
# 22     1219     MUSEO DEL ARMA DE INGENIEROS - ADUANA DE ORIBE
# 23     1024   MUSEO DEL AUTOMOVIL - AUTOMOVIL CLUB DEL URUGUAY
# 24     1224                    AUDITORIO NELLY GOITIÑO - SODRE
# 25      921        MUSEO DEL DESCUBRIMIENTO - APOSTADERO NAVAL
# 26     1022                    MUSEO DEL GAUCHO Y DE LA MONEDA
# 27     1025                                 MUSEO ENGELMAN-OST
# 28     1014  MUSEO HISTORICO FRANCISCANO SAN BERNARDINO DE ...
# 29      922                   MUSEO MILITAR 18 DE MAYO DE 1811
# ..      ...                                                ...
# 373     939  BIBLIOTECA AMNISTIA INTERNACIONAL - SECCION UR...
# 374    1222                           CINE LIFE PUNTA CARRETAS
# 375    1221                                 CINE LIFE ALFABETA
# 376    1012                   MUSEO NACIONAL DE ARTES VISUALES
# 377     903          BIBLIOTECA MUNICIPAL EDUARDO ACEVEDO DIAZ
# 378     896              BIBLIOTECA MUNICIPAL EVARISTO CIGANDA
# 379     895             BIBLIOTECA MUNICIPAL FRANCISCO SCHINCA
# 380     897               BIBLIOTECA MUNICIPAL HORACIO QUIROGA
# 381    1073                          BIBLIOTECA CENTRO MILITAR
# 382     881                                   TEATRO DE VERANO
# 383     885                        MUSEO MUNICIPAL DEL AZULEJO
# 384    1225              AUDITORIO NACIONAL ADELA RETA - SODRE
# 385     926  MUSEO ZOOLOGICO DOLORES PEREIRA DE ROSELL - VI...
# 386    1193  BIBLIOTECA PLANETARIO MUNICIPAL AGRIM GERMAN B...
# 387    1155  BIBLIOTECA INSTITUTO MEDICO DE PREVISION, ASIS...
# 388    1074  BIBLIOTECA CENTRO NACIONAL DE DOCUMENTACION E ...
# 389    1110  BIBLIOTECA ESCUELA DE ARTES Y ARTESANIAS DR PE...
# 390     899               BIBLIOTECA MUNICIPAL JAVIER DE VIANA
# 391     892                  BIBLIOTECA MUNICIPAL CARLOS ROXLO
# 392     901               BIBLIOTECA MUNICIPAL ERNESTO HERRERA
# 393     904            BIBLIOTECA MUNICIPAL FRANCISCO ESPINOLA
# 394     898           BIBLIOTECA MUNICIPAL ING JUAN MONTEVERDE
# 395     890                 BIBLIOTECA MUNICIPAL AURELIA VIERA
# 396     889                   BIBLIOTECA MUNICIPAL AMADO NERVO
# 397     828                        TEATRO ALIANZA URUGUAY-EEUU
# 398    1226                            FOTOGALERIA PARQUE RODO
# 399    1227                                  FOTOGALERIA PRADO
# 400    1228                           FOTOGALERIA CIUDAD VIEJA
# 401    1229                          FOTOGALERIA VILLA DOLORES
# 402    1230                 CENTRO DE FOTOGRAFIA DE MONTEVIDEO
#
#                                    direccion              x             y
# 0                                        NaN  576715.951621  6.137965e+06
# 1                                        NaN  572003.423883  6.141899e+06
# 2                                        NaN  568870.515398  6.149217e+06
# 3                                        NaN  574148.000000  6.137103e+06
# 4                                        NaN  572950.000000  6.140793e+06
# 5                                        NaN  573997.000000  6.137007e+06
